# %%
import pandas as pd

test1234 = pd.read_csv("Nemo.csv")

names = test1234["CompetitionName"].unique()
print(names)
# Out:
# <StringArray>
# [                 'World Championships',
#                              'Training',
#                    'Commonwealth Games',
#                 'British Championships',
#          'British Summer Championships',
#                 'Dave McCullagh Int LC',
#                    'Certification 2026',
#                'European Championships',
#                 'Scottish Short Course',
#                         'Olympic Games',
#               'Edinburgh International',
#                            'Time Trial',
#                 'Glasgow International',
#                    'Scottish Nationals',
#     'Challenge International de Geneve',
#                    'CERTIFICATION 2025',
#                      'AP International',
#                    'BUCS Championships',
#         'European Junior Championships',
#                    'CERTIFICATION 2022',
#          'Rotterdam Qualification Meet',
#                           'Sette Colli',
# ...
