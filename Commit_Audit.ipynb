# %%
import pandas as pd
import numpy as np
# !pip install openpyxl

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)
# Out:
# Requirement already satisfied: openpyxl in C:\Users\adhamz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in C:\Users\adhamz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openpyxl) (2.0.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\adhamz\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
df_commit = pd.read_csv('Commit2.csv')
print(df_commit.shape)
df_commit.head()
# Out:
# (8154, 190)
#          Date          About             by         workout_id          workout_date_time workout_date workout_time    workout_team_id workout_name  \
# 0  13-06-2026   Duncan Scott  Matt Milligan  T9A9jPRvhunZ7FExH  2026-06-13 07:00:00+00:00   13-06-2026     07:00:00  MTMbTHmYP85YHbQqd        AEC 1
# 1  13-06-2026    David Annis  Matt Milligan  qJYwQpMr2EMNZzYGi  2026-06-13 07:00:56+00:00   13-06-2026     07:00:56  MTMbTHmYP85YHbQqd        AEC 1
# 2  13-06-2026  Jack McMillan  Matt Milligan  qJYwQpMr2EMNZzYGi  2026-06-13 07:00:56+00:00   13-06-2026     07:00:56  MTMbTHmYP85YHbQqd        AEC 1
# 3  13-06-2026   George Smith  Matt Milligan  qJYwQpMr2EMNZzYGi  2026-06-13 07:00:56+00:00   13-06-2026     07:00:56  MTMbTHmYP85YHbQqd        AEC 1
# 4  13-06-2026   Holly McGill  Matt Milligan  zu4YaFWinqb7MzNta  2026-06-13 07:00:02+00:00   13-06-2026     07:00:02  MTMbTHmYP85YHbQqd        AEC 3
#
#                                         workout_text  workout_total_distance  workout_total_time         athlete_id athlete_first_name athlete_last_name  athlete_name  stroke_back  stroke_free  \
# 0  400 150Fr 50 Bk\n4x100 1-2 K 2x SPIKE 3-4 Pull...                    4000              4086.0  Zponc5irkrsnYQweo             Duncan             Scott  Duncan Scott        100.0       3200.0
# 1  800 SKPS\n400 Fr La1.5\n4x100 1-2 K 2x SPIKE 3...                    6000              7200.0  7qG9PmtqGzBnhi5mT              David             Annis   David Annis        400.0       4600.0
# 2  800 SKPS\n400 Fr La1.5\n4x100 1-2 K 2x SPIKE 3...                    6000              7200.0  KeeeiaXRLPcNCfuQa               Jack           McMilan  Jack McMilan        400.0       4600.0
# 3  800 SKPS\n400 Fr La1.5\n4x100 1-2 K 2x SPIKE 3...                    6000              7200.0  5WnMwkiYeS9vtedu8             George             Smith  George Smith        400.0       4600.0
# 4  800 SKPS\n400 Fr La1.5\n4x100 1-2 K 2x SPIKE 3...                    5000              5760.0  wg8bc4MiDSW2R363u              Holly            McGill  Holly McGill       1200.0       2900.0
#
#    stroke_fly  stroke_breast  stroke_im  stroke_mix  stroke_stroke  stroke_choice  stroke_free_im  stroke_form  stroke_worst  type_swim  type_kick  type_pull  type_mix  type_drill  type_band  \
# 0         NaN            NaN        NaN         NaN            NaN          200.0             NaN        500.0           NaN     2750.0      350.0      200.0       NaN       200.0        NaN
# 1       100.0          200.0        NaN         NaN            NaN          200.0             NaN        500.0           NaN     3600.0      550.0      400.0       NaN       200.0        NaN
# 2       100.0          200.0        NaN         NaN            NaN          200.0             NaN        500.0           NaN     3600.0      550.0      400.0       NaN       200.0        NaN
# 3       100.0          200.0        NaN         NaN            NaN          200.0             NaN        500.0           NaN     3600.0      550.0      400.0       NaN       200.0        NaN
# 4         NaN            NaN        NaN         NaN            NaN          400.0             NaN        500.0           NaN     3800.0      550.0      400.0       NaN       200.0        NaN
#
#    type_dps  type_hypoxic  type_paddles  type_scull  type_snorkel  type_technical_k  intensity_easy  intensity_lactate_1  intensity_lactate_2  intensity_lactate_3  intensity_lactate_4  \
# 0     500.0           NaN           NaN         NaN           NaN               NaN           100.0               1200.0                600.0                  NaN                  NaN
# 1      50.0           NaN        1200.0         NaN           NaN               NaN           300.0               2000.0               1200.0                300.0                  NaN
# 2      50.0           NaN        1200.0         NaN           NaN               NaN           300.0               2000.0               1200.0                300.0                  NaN
# 3      50.0           NaN        1200.0         NaN           NaN               NaN           300.0               2000.0               1200.0                300.0                  NaN
# 4      50.0           NaN           NaN         NaN           NaN               NaN           100.0               1600.0                 75.0                225.0                150.0
#
#    intensity_lactate_5  intensity_descend  intensity_negative_split  intensity_anaerobic_capacity  intensity_speed  intensity_aerobic_power  intensity_anaerobic_power  intensity_swim_down  \
# 0                  NaN                NaN                       NaN                          50.0             75.0                      NaN                        NaN                  NaN
# 1                  NaN                NaN                       NaN                          50.0              NaN                      NaN                        NaN                  NaN
# 2                  NaN                NaN                       NaN                          50.0              NaN                      NaN                        NaN                  NaN
# 3                  NaN                NaN                       NaN                          50.0              NaN                      NaN                        NaN                  NaN
# 4                375.0              300.0                       NaN                          50.0              NaN                     75.0                        NaN                400.0
#
#    intensity_race_warm_up  rawswoag_back_easy  rawswoag_back_lactate_1  rawswoag_back_lactate_2  rawswoag_back_lactate_3  rawswoag_back_lactate_4  rawswoag_back_lactate_5  rawswoag_back_descend  \
# 0                     NaN                 NaN                      NaN                      NaN                      NaN                      NaN                      NaN                    NaN
# 1                     NaN                 NaN                      NaN                      NaN                    100.0                      NaN                      NaN                    NaN
# 2                     NaN                 NaN                      NaN                      NaN                    100.0                      NaN                      NaN                    NaN
# 3                     NaN                 NaN                      NaN                      NaN                    100.0                      NaN                      NaN                    NaN
# 4                     NaN                 NaN                      NaN                     75.0                    225.0                    150.0                    375.0                  300.0
#
#    rawswoag_back_negative_split  rawswoag_back_anaerobic_capacity  rawswoag_back_speed  rawswoag_back_aerobic_power  rawswoag_back_anaerobic_power  rawswoag_free_easy  rawswoag_free_lactate_1  \
# 0                           NaN                               NaN                  NaN                          NaN                            NaN               100.0                   1200.0
# 1                           NaN                               NaN                  NaN                          NaN                            NaN               100.0                   2000.0
# 2                           NaN                               NaN                  NaN                          NaN                            NaN               100.0                   2000.0
# 3                           NaN                               NaN                  NaN                          NaN                            NaN               100.0                   2000.0
# 4                           NaN                               NaN                  NaN                         75.0                            NaN               100.0                   1600.0
#
#    rawswoag_free_lactate_2  rawswoag_free_lactate_3  rawswoag_free_lactate_4  rawswoag_free_lactate_5  rawswoag_free_descend  rawswoag_free_negative_split  rawswoag_free_anaerobic_capacity  \
# 0                    600.0                      NaN                      NaN                      NaN                    NaN                           NaN                               NaN
# 1                   1200.0                    100.0                      NaN                      NaN                    NaN                           NaN                               NaN
# 2                   1200.0                    100.0                      NaN                      NaN                    NaN                           NaN                               NaN
# 3                   1200.0                    100.0                      NaN                      NaN                    NaN                           NaN                               NaN
# 4                      NaN                      NaN                      NaN                      NaN                    NaN                           NaN                               NaN
#
#    rawswoag_free_speed  rawswoag_free_aerobic_power  rawswoag_free_anaerobic_power  rawswoag_fly_easy  rawswoag_fly_lactate_1  rawswoag_fly_lactate_2  rawswoag_fly_lactate_3  rawswoag_fly_lactate_4  \
# 0                 75.0                          NaN                            NaN                NaN                     NaN                     NaN                     NaN                     NaN
# 1                  NaN                          NaN                            NaN                NaN                     NaN                     NaN                     NaN                     NaN
# 2                  NaN                          NaN                            NaN                NaN                     NaN                     NaN                     NaN                     NaN
# 3                  NaN                          NaN                            NaN                NaN                     NaN                     NaN                     NaN                     NaN
# 4                  NaN                          NaN                            NaN                NaN                     NaN                     NaN                     NaN                     NaN
#
#    rawswoag_fly_lactate_5  rawswoag_fly_descend  rawswoag_fly_negative_split  rawswoag_fly_anaerobic_capacity  rawswoag_fly_speed  rawswoag_fly_aerobic_power  rawswoag_fly_anaerobic_power  \
# 0                     NaN                   NaN                          NaN                              NaN                 NaN                         NaN                           NaN
# 1                     NaN                   NaN                          NaN                              NaN                 NaN                         NaN                           NaN
# 2                     NaN                   NaN                          NaN                              NaN                 NaN                         NaN                           NaN
# 3                     NaN                   NaN                          NaN                              NaN                 NaN                         NaN                           NaN
# 4                     NaN                   NaN                          NaN                              NaN                 NaN                         NaN                           NaN
#
#    rawswoag_breast_easy  rawswoag_breast_lactate_1  rawswoag_breast_lactate_2  rawswoag_breast_lactate_3  rawswoag_breast_lactate_4  rawswoag_breast_lactate_5  rawswoag_breast_descend  \
# 0                   NaN                        NaN                        NaN                        NaN                        NaN                        NaN                      NaN
# 1                   NaN                        NaN                        NaN                      100.0                        NaN                        NaN                      NaN
# 2                   NaN                        NaN                        NaN                      100.0                        NaN                        NaN                      NaN
# 3                   NaN                        NaN                        NaN                      100.0                        NaN                        NaN                      NaN
# 4                   NaN                        NaN                        NaN                        NaN                        NaN                        NaN                      NaN
#
#    rawswoag_breast_negative_split  rawswoag_breast_anaerobic_capacity  rawswoag_breast_speed  rawswoag_breast_aerobic_power  rawswoag_breast_anaerobic_power  rawswoag_im_easy  rawswoag_im_lactate_1  \
# 0                             NaN                                 NaN                    NaN                            NaN                              NaN               NaN                    NaN
# 1                             NaN                                 NaN                    NaN                            NaN                              NaN               NaN                    NaN
# 2                             NaN                                 NaN                    NaN                            NaN                              NaN               NaN                    NaN
# 3                             NaN                                 NaN                    NaN                            NaN                              NaN               NaN                    NaN
# 4                             NaN                                 NaN                    NaN                            NaN                              NaN               NaN                    NaN
#
#    rawswoag_im_lactate_2  rawswoag_im_lactate_3  rawswoag_im_lactate_4  rawswoag_im_lactate_5  rawswoag_im_descend  rawswoag_im_negative_split  rawswoag_im_anaerobic_capacity  rawswoag_im_speed  \
# 0                    NaN                    NaN                    NaN                    NaN                  NaN                         NaN                             NaN                NaN
# 1                    NaN                    NaN                    NaN                    NaN                  NaN                         NaN                             NaN                NaN
# 2                    NaN                    NaN                    NaN                    NaN                  NaN                         NaN                             NaN                NaN
# 3                    NaN                    NaN                    NaN                    NaN                  NaN                         NaN                             NaN                NaN
# 4                    NaN                    NaN                    NaN                    NaN                  NaN                         NaN                             NaN                NaN
#
#    rawswoag_im_aerobic_power  rawswoag_im_anaerobic_power  rawswoag_mix_easy  rawswoag_mix_lactate_1  rawswoag_mix_lactate_2  rawswoag_mix_lactate_3  rawswoag_mix_lactate_4  rawswoag_mix_lactate_5  \
# 0                        NaN                          NaN                NaN                     NaN                     NaN                     NaN                     NaN                     NaN
# 1                        NaN                          NaN                NaN                     NaN                     NaN                     NaN                     NaN                     NaN
# 2                        NaN                          NaN                NaN                     NaN                     NaN                     NaN                     NaN                     NaN
# 3                        NaN                          NaN                NaN                     NaN                     NaN                     NaN                     NaN                     NaN
# 4                        NaN                          NaN                NaN                     NaN                     NaN                     NaN                     NaN                     NaN
#
#    rawswoag_mix_descend  rawswoag_mix_negative_split  rawswoag_mix_anaerobic_capacity  rawswoag_mix_speed  rawswoag_mix_aerobic_power  rawswoag_mix_anaerobic_power  rawswoag_stroke_easy  \
# 0                   NaN                          NaN                              NaN                 NaN                         NaN                           NaN                   NaN
# 1                   NaN                          NaN                              NaN                 NaN                         NaN                           NaN                   NaN
# 2                   NaN                          NaN                              NaN                 NaN                         NaN                           NaN                   NaN
# 3                   NaN                          NaN                              NaN                 NaN                         NaN                           NaN                   NaN
# 4                   NaN                          NaN                              NaN                 NaN                         NaN                           NaN                   NaN
#
#    rawswoag_stroke_lactate_1  rawswoag_stroke_lactate_2  rawswoag_stroke_lactate_3  rawswoag_stroke_lactate_4  rawswoag_stroke_lactate_5  rawswoag_stroke_descend  rawswoag_stroke_negative_split  \
# 0                        NaN                        NaN                        NaN                        NaN                        NaN                      NaN                             NaN
# 1                        NaN                        NaN                        NaN                        NaN                        NaN                      NaN                             NaN
# 2                        NaN                        NaN                        NaN                        NaN                        NaN                      NaN                             NaN
# 3                        NaN                        NaN                        NaN                        NaN                        NaN                      NaN                             NaN
# 4                        NaN                        NaN                        NaN                        NaN                        NaN                      NaN                             NaN
#
#    rawswoag_stroke_anaerobic_capacity  rawswoag_stroke_speed  rawswoag_stroke_aerobic_power  rawswoag_stroke_anaerobic_power  rawswoag_choice_easy  rawswoag_choice_lactate_1  \
# 0                                 NaN                    NaN                            NaN                              NaN                   NaN                        NaN
# 1                                 NaN                    NaN                            NaN                              NaN                 200.0                        NaN
# 2                                 NaN                    NaN                            NaN                              NaN                 200.0                        NaN
# 3                                 NaN                    NaN                            NaN                              NaN                 200.0                        NaN
# 4                                 NaN                    NaN                            NaN                              NaN                   NaN                        NaN
#
#    rawswoag_choice_lactate_2  rawswoag_choice_lactate_3  rawswoag_choice_lactate_4  rawswoag_choice_lactate_5  rawswoag_choice_descend  rawswoag_choice_negative_split  \
# 0                        NaN                        NaN                        NaN                        NaN                      NaN                             NaN
# 1                        NaN                        NaN                        NaN                        NaN                      NaN                             NaN
# 2                        NaN                        NaN                        NaN                        NaN                      NaN                             NaN
# 3                        NaN                        NaN                        NaN                        NaN                      NaN                             NaN
# 4                        NaN                        NaN                        NaN                        NaN                      NaN                             NaN
#
#    rawswoag_choice_anaerobic_capacity  rawswoag_choice_speed  rawswoag_choice_aerobic_power  rawswoag_choice_anaerobic_power  rawswoag_free_im_easy  rawswoag_free_im_lactate_1  \
# 0                                 NaN                    NaN                            NaN                              NaN                    NaN                         NaN
# 1                                 NaN                    NaN                            NaN                              NaN                    NaN                         NaN
# 2                                 NaN                    NaN                            NaN                              NaN                    NaN                         NaN
# 3                                 NaN                    NaN                            NaN                              NaN                    NaN                         NaN
# 4                                 NaN                    NaN                            NaN                              NaN                    NaN                         NaN
#
#    rawswoag_free_im_lactate_2  rawswoag_free_im_lactate_3  rawswoag_free_im_lactate_4  rawswoag_free_im_lactate_5  rawswoag_free_im_descend  rawswoag_free_im_negative_split  \
# 0                         NaN                         NaN                         NaN                         NaN                       NaN                              NaN
# 1                         NaN                         NaN                         NaN                         NaN                       NaN                              NaN
# 2                         NaN                         NaN                         NaN                         NaN                       NaN                              NaN
# 3                         NaN                         NaN                         NaN                         NaN                       NaN                              NaN
# 4                         NaN                         NaN                         NaN                         NaN                       NaN                              NaN
#
#    rawswoag_free_im_anaerobic_capacity  rawswoag_free_im_speed  rawswoag_free_im_aerobic_power  rawswoag_free_im_anaerobic_power  rawswoag_form_easy  rawswoag_form_lactate_1  \
# 0                                  NaN                     NaN                             NaN                               NaN                 NaN                      NaN
# 1                                  NaN                     NaN                             NaN                               NaN                 NaN                      NaN
# 2                                  NaN                     NaN                             NaN                               NaN                 NaN                      NaN
# 3                                  NaN                     NaN                             NaN                               NaN                 NaN                      NaN
# 4                                  NaN                     NaN                             NaN                               NaN                 NaN                      NaN
#
#    rawswoag_form_lactate_2  rawswoag_form_lactate_3  rawswoag_form_lactate_4  rawswoag_form_lactate_5  rawswoag_form_descend  rawswoag_form_negative_split  rawswoag_form_anaerobic_capacity  \
# 0                      NaN                      NaN                      NaN                      NaN                    NaN                           NaN                              50.0
# 1                      NaN                      NaN                      NaN                      NaN                    NaN                           NaN                              50.0
# 2                      NaN                      NaN                      NaN                      NaN                    NaN                           NaN                              50.0
# 3                      NaN                      NaN                      NaN                      NaN                    NaN                           NaN                              50.0
# 4                      NaN                      NaN                      NaN                      NaN                    NaN                           NaN                              50.0
#
#    rawswoag_form_speed  rawswoag_form_aerobic_power  rawswoag_form_anaerobic_power  rawswoag_main_easy  rawswoag_main_lactate_1  rawswoag_main_lactate_2  rawswoag_main_lactate_3  \
# 0                  NaN                          NaN                            NaN               100.0                   1200.0                    600.0                      NaN
# 1                  NaN                          NaN                            NaN               100.0                   2000.0                   1200.0                    100.0
# 2                  NaN                          NaN                            NaN               100.0                   2000.0                   1200.0                    100.0
# 3                  NaN                          NaN                            NaN                 NaN                      NaN                      NaN                    100.0
# 4                  NaN                          NaN                            NaN                 NaN                      NaN                     75.0                    225.0
#
#    rawswoag_main_lactate_4  rawswoag_main_lactate_5  rawswoag_main_descend  rawswoag_main_negative_split  rawswoag_main_anaerobic_capacity  rawswoag_main_speed  rawswoag_main_aerobic_power  \
# 0                      NaN                      NaN                    NaN                           NaN                              50.0                 75.0                          NaN
# 1                      NaN                      NaN                    NaN                           NaN                              50.0                  NaN                          NaN
# 2                      NaN                      NaN                    NaN                           NaN                              50.0                  NaN                          NaN
# 3                      NaN                      NaN                    NaN                           NaN                              50.0                  NaN                          NaN
# 4                    150.0                    375.0                  300.0                           NaN                              50.0                  NaN                         75.0
#
#    rawswoag_main_anaerobic_power  rawswoag_main  stroke_main  Daily Workout Total Distance                            event-uuid                            group-uuid
# 0                            NaN         2025.0       3700.0                        4000.0  fa8abfd4-876b-430b-8866-007dac9f6be5  6c284d99-2334-456c-bddc-f96591163be3
# 1                            NaN         3450.0       5100.0                        6000.0  7a37d469-596b-41b1-9c3e-462ddc5f54b9  c33098eb-a129-4f96-9c73-52dc06417637
# 2                            NaN         3450.0       5100.0                        6000.0  3f397d49-40f1-4164-b958-069f44719188  874b017b-e85f-4718-bf12-2b188956057c
# 3                            NaN          150.0        700.0                        6000.0  7493b399-fc4c-4275-8af5-a271299e1ed4  26f13b8f-9e8f-46b4-b70f-f1a66125ea16
# 4                            NaN         1250.0       1700.0                        5000.0  c284ed94-7967-43b4-a331-6fb8ce8b495f  525e1ed8-8cb8-45f4-8ed6-43f0c491fa50

# %%
###Standardised Dataset Audit Function
##Produces consistent variable summary and temporal evaluation ouputs

##Usage:
    ##run_audit(df, dataset_name, athlete_col='About', date_col='Date')

##Outputs an Excel file with two sheets:
  #1. Variable Summary (one row per variable with flags and role)
  #2. Temporal Evaluation (dataset-level coverage statistics)

# %%
def run_audit(df, dataset_name, athlete_col='About', date_col='Date',
              missing_threshold=70, constant_threshold=1, id_threshold=95):
    
    """
    Runs a standardised audit on a dataset and saves results to Excel.
    
    Parameters:
    
    df
        The dataset to audit
    dataset_name
        Used for the output filename 
    athlete_col
        Column containing athlete identifier (default: 'About')
    date_col
        Column containing date (default: 'Date')
    missing_threshold
        % missing, flags it as high missing (flag_high_missing = TRUE) (default: over 70)
    constant_threshold
        % unique, flags it as a likely constant (flag_near_constant = TRUE) (default: under 1)
    id_threshold : 
        % unique, flags it as a likely identifier (flag_identifier = TRUE) (default: over 95)
    """

    
    ##Variable Summary (This produces sheet 1):
    
    n = len(df) #total number of rows, for calculations later
    rows = [] #Creates an empty list to loop through every column 

    for col in df.columns:
        n_missing = df[col].isnull().sum()
        pct_missing = round(n_missing / n * 100, 2)
        pct_unique = round(df[col].nunique() / n * 100, 2)

        flag_high_missing = pct_missing >= missing_threshold
        flag_near_constant = pct_unique < constant_threshold
        flag_identifier = pct_unique >= id_threshold
        flag_structurally_empty = pct_missing == 100

        #Auto-assign variable role
        if flag_structurally_empty:
            role = 'Exclude (structurally empty)'
        elif flag_identifier:
            role = 'Identifier'
        elif flag_near_constant:
            role = 'Exclude (near constant)'
        elif flag_high_missing:
            role = 'Review (high missingness)'
        else:
            role = 'Predictor candidate'

        rows.append({
            'variable': col,
            'dtype': str(df[col].dtype),
            'n_missing': n_missing,
            'pct_missing': pct_missing,
            'pct_unique': pct_unique,
            'flag_high_missing': flag_high_missing,
            'flag_near_constant': flag_near_constant,
            'flag_identifier': flag_identifier,
            'flag_structurally_empty': flag_structurally_empty,
            'variable_role': role,})

    var_summary = pd.DataFrame(rows)

    ##Temporal Evaluation (this produces Sheet 2):
    
    temporal_row = {} #creates empty dictionary to fill with temporal measures

    if date_col in df.columns:
        df[date_col] = pd.to_datetime(df[date_col], errors='coerce', dayfirst=True)
        temporal_row['min_date'] = df[date_col].min()
        temporal_row['max_date'] = df[date_col].max()
    else:
        temporal_row['min_date'] = 'Date column not found'
        temporal_row['max_date'] = 'Date column not found'

    if athlete_col in df.columns:
        temporal_row['n_athletes'] = df[athlete_col].nunique() #number of athletes

        #athlete observation counts
        obs_per_athlete = df.groupby(athlete_col).size()
        temporal_row['mean_obs_per_athlete']   = round(obs_per_athlete.mean(), 2) #round to two decimal places
        temporal_row['median_obs_per_athlete'] = obs_per_athlete.median()
        temporal_row['min_obs_per_athlete']    = obs_per_athlete.min()
        temporal_row['max_obs_per_athlete']    = obs_per_athlete.max()

        #athlete gap between consecutive observations
        if date_col in df.columns:
            gaps = (
                df.sort_values([athlete_col, date_col])
                .groupby(athlete_col)[date_col]
                .diff()
                .dt.days
                .dropna() )
            temporal_row['mean_days_between_obs']   = round(gaps.mean(), 2)
            temporal_row['min_days_between_obs']    = gaps.min()
            temporal_row['max_days_between_obs']    = gaps.max()
        else:
            temporal_row['mean_days_between_obs'] = 'N/A'
            temporal_row['min_days_between_obs']  = 'N/A'
            temporal_row['max_days_between_obs']  = 'N/A'
    else: #if wrong column name is enetered
        temporal_row['n_athletes'] = 'Athlete column not found'
        for k in ['mean_obs_per_athlete','median_obs_per_athlete',
                  'min_obs_per_athlete','max_obs_per_athlete',
                  'mean_days_between_obs','min_days_between_obs',
                  'max_days_between_obs']:
            temporal_row[k] = 'N/A'

    ##auto-generate interpretation
    
    try:
        interp = (
            f"{dataset_name} audit covers {temporal_row['n_athletes']} athletes "
            f"from {str(temporal_row['min_date'])[:10]} to "
            f"{str(temporal_row['max_date'])[:10]}. "
            f"Mean observations per athlete: {temporal_row['mean_obs_per_athlete']} "
            f"(range {temporal_row['min_obs_per_athlete']}–"
            f"{temporal_row['max_obs_per_athlete']}). "
            f"Mean gap between observations: {temporal_row['mean_days_between_obs']} days "
            f"(range {temporal_row['min_days_between_obs']}–"
            f"{temporal_row['max_days_between_obs']} days).")
    except Exception:
        interp = 'Could not auto-generate interpretation — check column names.'

    temporal_row['interpretation'] = interp
    temporal_df = pd.DataFrame([temporal_row])

    ##summary counts for quick reference
    
    role_counts = var_summary['variable_role'].value_counts()
    print(f"\n{'='*50}") #creates a visual divider line
    print(f"AUDIT COMPLETE: {dataset_name}")
    print(f"{'='*50}")
    print(f"Total variables: {len(var_summary)}")
    print(f"Total rows: {n}")
    print(f"\nVariable role breakdown:")
    for role, count in role_counts.items(): #loops through each category and it's count
        print(f"  {role:<40} {count}") #"40" makes it 40 characters wide to create neat column
    print(f"\nTemporal coverage:")
    print(f"Athletes: {temporal_row['n_athletes']}")
    print(f"Date range: {str(temporal_row['min_date'])[:10]} to {str(temporal_row['max_date'])[:10]}") #"10" takes the first 10 characters (just yyyy-mm-dd)
    print(f"Mean obs/athlete: {temporal_row['mean_obs_per_athlete']}")
    print(f"Mean gap (days): {temporal_row['mean_days_between_obs']}")

    ##save to Excel 
    
    filename = f"{dataset_name.replace(' ', '_')}_audit.xlsx"
    with pd.ExcelWriter(filename, engine='openpyxl') as writer: #"openxyl" enables reading and writing excel files
        var_summary.to_excel(writer, sheet_name='Variable Summary', index=False)
        temporal_df.to_excel(writer, sheet_name='Temporal Evaluation', index=False)

    print(f"\nSaved: {filename}")
    return var_summary, temporal_df

# %%
###Run the audit on Commit2.csv:

var_summary, temporal = run_audit(
    df=df_commit,
    dataset_name='Commit_Audit',
    athlete_col='About',
    date_col='Date')
# Out:
# ==================================================
# AUDIT COMPLETE: Commit_Audit
# ==================================================
# Total variables: 190
# Total rows: 8154
#
# Variable role breakdown:
#   Exclude (near constant)                  120
#   Exclude (structurally empty)             46
#   Predictor candidate                      20
#   Review (high missingness)                2
#   Identifier                               2
#
# Temporal coverage:
# Athletes: 16
# Date range: 2025-01-06 to 2026-06-13
# Mean obs/athlete: 509.62
# Mean gap (days): 0.9
#
# Saved: Commit_Audit_audit.xlsx

# %%
#check what the 20 predictor candidates actually are
print(f"the predictor candidates are", var_summary[var_summary['variable_role'] == 'Predictor candidate']['variable'].tolist())

#check what the 2 identifiers are
print(f"the identifiers are", var_summary[var_summary['variable_role'] == 'Identifier']['variable'].tolist())
# Out:
# the predictor candidates are ['Date', 'workout_id', 'workout_date_time', 'workout_date', 'workout_time', 'workout_name', 'workout_text', 'workout_total_distance', 'workout_total_time', 'stroke_free', 'stroke_form', 'type_swim', 'type_kick', 'type_pull', 'intensity_easy', 'intensity_lactate_1', 'rawswoag_free_easy', 'rawswoag_free_lactate_1', 'rawswoag_main', 'stroke_main']
# the identifiers are ['event-uuid', 'group-uuid']
