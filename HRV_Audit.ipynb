# %%
import pandas as pd
import numpy as np
# !pip install openpyxl

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\adhamz\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
df_hrv = pd.read_csv('HRV.csv')
print(df_hrv.shape)
df_hrv.head()
# Out:
# (1701, 61)
#          Date           About             by Do you have symptoms of Illness today  Illness Alert  HRV  Availability Availability Reason Illness Injured Other  \
# 0  15/06/2026      Dean Fearn  Matt Milligan                                    No            NaN  8.3           NaN                  []      No      No    No
# 1  15/06/2026     Lucy Grieve  Matt Milligan                                    No            NaN  7.0           NaN                  []      No      No    No
# 2  15/06/2026  Katie Shanahan  Matt Milligan                                    No            NaN  8.4           NaN                  []      No      No    No
# 3  15/06/2026    Holly McGill  Matt Milligan                                    No            NaN  8.7           NaN                  []      No      No    No
# 4  15/06/2026    George Smith  Matt Milligan                                    No            NaN  8.0           NaN                  []      No      No    No
#
#   How are your energy levels this morning How was your sleep quality last night?  How motivated are you to train today? How is your mental energy this morning?  \
# 0                                  Normal                                   Good                                   38.0                                      42
# 1                                  Normal                                     84                                   56.0                                      65
# 2                                  Normal                                     50                                   64.0                                      80
# 3                                  Normal                                     54                                   59.0                                      65
# 4                                  Normal                                     31                                   34.0                                      34
#
#   How is your muscle soreness this morning? How fatigued are you this morning? How would you describe your lifestyle? Were you travelling yesterday? Are you currently menstruating ?  \
# 0                                        39                                 40                                     27                             No                               No
# 1                                        60                                 54                                     50                             No                               No
# 2                                        50                                 50                                      0                             No                               No
# 3                                        50                                 50                                    NaN                             No                               No
# 4                                        50                                 50                                      0                             No                               No
#
#    Yesterday's Pool AM Volume (m)  Yesterday's Pool PM Volume (m)    Pool AM RPE Pool PM RPE S&C RPE  Did you complete any additional land training yesterday  \
# 0                             NaN                             NaN            NaN         NaN     NaN                                                NaN
# 1                             NaN                             NaN  7 - Very Hard         NaN     NaN                                                NaN
# 2                             NaN                             NaN            NaN         NaN     NaN                                                NaN
# 3                             NaN                             NaN            NaN         NaN     NaN                                                NaN
# 4                             NaN                             NaN            NaN         NaN     NaN                                                NaN
#
#   What additional land training did you complete yesterday Core Selected Run Selected Bike Selected Yoga Selected Pilates Selected Swim Bench Selected Land Cardio Selected  Core RPE  Run RPE  \
# 0                                                 []                  No           No            No            No               No                  No                   No       NaN      NaN
# 1                                                 []                  No           No            No            No               No                  No                   No       NaN      NaN
# 2                                                 []                  No           No            No            No               No                  No                   No       NaN      NaN
# 3                                                 []                  No           No            No            No               No                  No                   No       NaN      NaN
# 4                                                 []                  No           No            No            No               No                  No                   No       NaN      NaN
#
#    Bike RPE  Yoga RPE  Pilates RPE  Swim Bench RPE  Land Cardio RPE           Athlete_Date_Key  HRV Value  How are your energy levels this morning Value  Pool AM RPE Value  Pool PM RPE Value  \
# 0       NaN       NaN          NaN             NaN              NaN      Dean Fearn-15/06/2026        8.3                                            3.0                NaN                NaN
# 1       NaN       NaN          NaN             NaN              NaN     Lucy Grieve-15/06/2026        7.0                                            3.0                7.0                NaN
# 2       NaN       NaN          NaN             NaN              NaN  Katie Shanahan-15/06/2026        8.4                                            3.0                NaN                NaN
# 3       NaN       NaN          NaN             NaN              NaN    Holly McGill-15/06/2026        8.7                                            3.0                NaN                NaN
# 4       NaN       NaN          NaN             NaN              NaN    George Smith-15/06/2026        8.0                                            3.0                NaN                NaN
#
#    S&C RPE Value  Core RPE Value  Run RPE Value  Bike RPE Value  Yoga RPE Value  Pilates RPE Value  Swim Bench RPE Value  Land Cardio RPE Value  Sleep Value  Fatigue Value  Mental Energy Value  \
# 0            NaN             NaN            NaN             NaN             NaN                NaN                   NaN                    NaN        100.0           40.0                 42.0
# 1            NaN             NaN            NaN             NaN             NaN                NaN                   NaN                    NaN         84.0           54.0                 65.0
# 2            NaN             NaN            NaN             NaN             NaN                NaN                   NaN                    NaN         50.0           50.0                 80.0
# 3            NaN             NaN            NaN             NaN             NaN                NaN                   NaN                    NaN         54.0           50.0                 65.0
# 4            NaN             NaN            NaN             NaN             NaN                NaN                   NaN                    NaN         31.0           50.0                 34.0
#
#    Motivation Value  Pool RPE Avg                            event-uuid                            group-uuid
# 0              38.0           NaN  6caeff9c-6705-4f26-b6f9-02f7dbbf0a6f  3a08eb1f-aee5-4633-ab2b-ac93537a3c36
# 1              56.0           7.0  6da0467c-f782-480a-ad35-989f24eefb17  ef270d8e-f864-4bb1-8997-c50d7d3272dc
# 2              64.0           NaN  43978393-1fb1-43bb-97d4-796b78e97a13  4ba86fb7-9289-45bf-ac9d-5f7816decef5
# 3              59.0           NaN  df74adc8-ceaa-4604-bfb0-d0818a646f68  9c89296d-7219-4395-9529-19215538ac1c
# 4              34.0           NaN  9563f558-c1c4-4c1f-bb15-c4337d687c60  8b14a070-506a-4e36-94ac-0d569bfb30ba

# %%
###Standardised Dataset Audit Function - VERSION 2
  ##Changes from V1:
    #Adding date/athlete col exlcusion to avoid them slipping as predictor candidates
    #Adding keyword based identifier detection 
    #Adding review category ("sparse") for near con-stant but informative variable (e.g. intensities)

##Produces consistent variable summary and temporal evaluation ouputs

##Usage:
    ##run_audit(df, dataset_name, athlete_col='About', date_col='Date')

##Outputs an Excel file with two sheets:
  #1. Variable Summary (one row per variable with flags and role)
  #2. Temporal Evaluation (dataset-level coverage statistics)

# %%
def run_audit(df, dataset_name, athlete_col='About', date_col='Date',
              missing_threshold=70, constant_threshold=1, id_threshold=95):
    
    """
    Runs a standardised audit on a dataset and saves results to Excel.
    
    Parameters:
    
    df
        The dataset to audit
    dataset_name
        Used for the output filename 
    athlete_col
        Column containing athlete identifier (default: 'About')
    date_col
        Column containing date (default: 'Date')
    missing_threshold
        % missing, flags it as high missing (flag_high_missing = TRUE) (default: over 70)
    constant_threshold
        % unique, flags it as a likely constant (flag_near_constant = TRUE) (default: under 1)
    id_threshold : 
        % unique, flags it as a likely identifier (flag_identifier = TRUE) (default: over 95)
    """

    
    ##Variable Summary (This produces sheet 1):
    
    n = len(df) #total number of rows, for calculations later
    rows = [] #Creates an empty list to loop through every column 

    for col in df.columns:
        n_missing = df[col].isnull().sum()
        pct_missing = round(n_missing / n * 100, 2)
        pct_unique = round(df[col].nunique() / n * 100, 2)

        flag_high_missing = pct_missing >= missing_threshold
        flag_near_constant = pct_unique < constant_threshold
        flag_identifier = pct_unique >= id_threshold
        flag_structurally_empty = pct_missing == 100

        #Keyword to assign identifiers
        identifier_keywords = ['id', 'uuid', 'date', 'time', 'key']
        is_keyword_identifier = any(kw in col.lower() for kw in identifier_keywords)

        #Check if column is datetime dtype 
        is_datetime = pd.api.types.is_datetime64_any_dtype(df[col])

        #Auto-assign variable role
        if col == date_col or col == athlete_col:
            role = 'Identifier'
        elif flag_structurally_empty:
            role = 'Exclude (structurally empty)'
        elif is_datetime or is_keyword_identifier:
            role = 'Identifier'
        elif flag_identifier:
            role = 'Identifier'
        elif flag_near_constant:
            #Check if variable is still informative vs truly constant
            non_missing = df[col].dropna()
            non_zero = non_missing[non_missing != 0]
            if len(non_zero) > 0 and non_zero.nunique() > 3:
                rol = 'Sparse - Review'
            else:
                role = 'Exclude (near constant)'
        elif flag_high_missing:
            role = 'Review (high missingness)'
        else:
            role = 'Predictor candidate'

        rows.append({
            'variable': col,
            'dtype': str(df[col].dtype),
            'n_missing': n_missing,
            'pct_missing': pct_missing,
            'pct_unique': pct_unique,
            'flag_high_missing': flag_high_missing,
            'flag_near_constant': flag_near_constant,
            'flag_identifier': flag_identifier,
            'flag_structurally_empty': flag_structurally_empty,
            'variable_role': role,})

    var_summary = pd.DataFrame(rows)

    ##Temporal Evaluation (this produces Sheet 2):
    
    temporal_row = {} #creates empty dictionary to fill with temporal measures

    if date_col in df.columns:
        df[date_col] = pd.to_datetime(df[date_col], errors='coerce', dayfirst=True)
        temporal_row['min_date'] = df[date_col].min()
        temporal_row['max_date'] = df[date_col].max()
    else:
        temporal_row['min_date'] = 'Date column not found'
        temporal_row['max_date'] = 'Date column not found'

    if athlete_col in df.columns:
        temporal_row['n_athletes'] = df[athlete_col].nunique() #number of athletes

        #athlete observation counts
        obs_per_athlete = df.groupby(athlete_col).size()
        temporal_row['mean_obs_per_athlete']   = round(obs_per_athlete.mean(), 2) #round to two decimal places
        temporal_row['median_obs_per_athlete'] = obs_per_athlete.median()
        temporal_row['min_obs_per_athlete']    = obs_per_athlete.min()
        temporal_row['max_obs_per_athlete']    = obs_per_athlete.max()

        #athlete gap between consecutive observations
        if date_col in df.columns:
            gaps = (
                df.sort_values([athlete_col, date_col])
                .groupby(athlete_col)[date_col]
                .diff()
                .dt.days
                .dropna() )
            temporal_row['mean_days_between_obs']   = round(gaps.mean(), 2)
            temporal_row['min_days_between_obs']    = gaps.min()
            temporal_row['max_days_between_obs']    = gaps.max()
        else:
            temporal_row['mean_days_between_obs'] = 'N/A'
            temporal_row['min_days_between_obs']  = 'N/A'
            temporal_row['max_days_between_obs']  = 'N/A'
    else: #if wrong column name is enetered
        temporal_row['n_athletes'] = 'Athlete column not found'
        for k in ['mean_obs_per_athlete','median_obs_per_athlete',
                  'min_obs_per_athlete','max_obs_per_athlete',
                  'mean_days_between_obs','min_days_between_obs',
                  'max_days_between_obs']:
            temporal_row[k] = 'N/A'

    ##auto-generate interpretation
    
    try:
        interp = (
            f"{dataset_name} audit covers {temporal_row['n_athletes']} athletes "
            f"from {str(temporal_row['min_date'])[:10]} to "
            f"{str(temporal_row['max_date'])[:10]}. "
            f"Mean observations per athlete: {temporal_row['mean_obs_per_athlete']} "
            f"(range {temporal_row['min_obs_per_athlete']}–"
            f"{temporal_row['max_obs_per_athlete']}). "
            f"Mean gap between observations: {temporal_row['mean_days_between_obs']} days "
            f"(range {temporal_row['min_days_between_obs']}–"
            f"{temporal_row['max_days_between_obs']} days).")
    except Exception:
        interp = 'Could not auto-generate interpretation — check column names.'

    temporal_row['interpretation'] = interp
    temporal_df = pd.DataFrame([temporal_row])

    ##summary counts for quick reference
    
    role_counts = var_summary['variable_role'].value_counts()
    print(f"\n{'='*50}") #creates a visual divider line
    print(f"AUDIT COMPLETE: {dataset_name}")
    print(f"{'='*50}")
    print(f"Total variables: {len(var_summary)}")
    print(f"Total rows: {n}")
    print(f"\nVariable role breakdown:")
    for role, count in role_counts.items(): #loops through each category and it's count
        print(f"  {role:<40} {count}") #"40" makes it 40 characters wide to create neat column
    print(f"\nTemporal coverage:")
    print(f"Athletes: {temporal_row['n_athletes']}")
    print(f"Date range: {str(temporal_row['min_date'])[:10]} to {str(temporal_row['max_date'])[:10]}") #"10" takes the first 10 characters (just yyyy-mm-dd)
    print(f"Mean obs/athlete: {temporal_row['mean_obs_per_athlete']}")
    print(f"Mean gap (days): {temporal_row['mean_days_between_obs']}")

    ##save to Excel 
    
    filename = f"{dataset_name.replace(' ', '_')}_audit.xlsx"
    with pd.ExcelWriter(filename, engine='openpyxl') as writer: #"openxyl" enables reading and writing excel files
        var_summary.to_excel(writer, sheet_name='Variable Summary', index=False)
        temporal_df.to_excel(writer, sheet_name='Temporal Evaluation', index=False)

    print(f"\nSaved: {filename}")
    return var_summary, temporal_df

# %%
###Run the audit on HRV.csv:

var_summary, temporal = run_audit(
    df=df_hrv,
    dataset_name='HRV and Readiness2',
    athlete_col='About',
    date_col='Date')
# Out:
# ==================================================
# AUDIT COMPLETE: HRV and Readiness2
# ==================================================
# Total variables: 61
# Total rows: 1701
#
# Variable role breakdown:
#   Exclude (structurally empty)             22
#   Predictor candidate                      17
#   Exclude (near constant)                  16
#   Identifier                               6
#
# Temporal coverage:
# Athletes: 16
# Date range: 2026-01-23 to 2026-06-15
# Mean obs/athlete: 106.31
# Mean gap (days): 1.28
#
# Saved: HRV_and_Readiness2_audit.xlsx

# %%
#check what the 17 predictor candidates actually are
print(f"the predictor candidates are", var_summary[var_summary['variable_role'] == 'Predictor candidate']['variable'].tolist())

#check what the 6 identifiers are
print(f"the identifiers are", var_summary[var_summary['variable_role'] == 'Identifier']['variable'].tolist())
# Out:
# the predictor candidates are ['HRV', 'How was your sleep quality last night?', 'How motivated are you to train today?', 'How is your mental energy this morning?', 'How is your muscle soreness this morning?', 'How fatigued are you this morning?', 'How would you describe your lifestyle?', 'HRV Value', 'How are your energy levels this morning Value', 'Pool AM RPE Value', 'Pool PM RPE Value', 'S&C RPE Value', 'Sleep Value', 'Fatigue Value', 'Mental Energy Value', 'Motivation Value', 'Pool RPE Avg']
# the identifiers are ['Date', 'About', 'What additional land training did you complete yesterday', 'Athlete_Date_Key', 'event-uuid', 'group-uuid']
