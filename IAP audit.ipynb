# %%
import pandas as pd
import numpy as np
# !pip install openpyxl

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\adhamz\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
df_iap = pd.read_csv('IAP 3.csv')
print(df_iap.shape)
df_iap.head()
# Out:
# (372, 33)
#          Date            About  Index  Index Sum First Name  Last Name        Full Name Full Name Reverse     Sex Date of Birth  Age Day of the Week  Week Month Month with Number  Year  Year Week  \
# 0  27-04-2026   Katie Shanahan      1          1      Katie   Shanahan   Katie Shanahan    Shanahan Katie  Female    25-06-2004   21             Mon    17   Apr            04 Apr  2026  2026 - 17
# 1  27-04-2026     Duncan Scott      1          1     Duncan      Scott     Duncan Scott      Scott Duncan    Male    06-05-1997   28             Mon    17   Apr            04 Apr  2026  2026 - 17
# 2  27-04-2026      David Annis      1          1      David      Annis      David Annis       Annis David    Male    12-04-2006   20             Mon    17   Apr            04 Apr  2026  2026 - 17
# ...

# %%
# %run "./audit_utils.ipynb"

# %%
var_summary, temporal = run_audit(
    df=df_iap,
    dataset_name='IAP',
    athlete_col='About',
    date_col='Date'
)
# Out:
# ...
# AUDIT COMPLETE: IAP
# ...
# Total variables: 33
# Total rows: 372
#
# Variable role breakdown:
#   Identifier                               15
#   Predictor candidate                      9
#   Exclude (near constant)                  6
#   Sparse categorical - review              2
#   Review (high missingness)                1
#
# Temporal coverage:
# Athletes: 16
# Date range: 2025-09-29 to 2026-04-27
# Mean obs/athlete: 23.25
# Mean gap (days): 9.44
#
# Saved: IAP_audit.xlsx
