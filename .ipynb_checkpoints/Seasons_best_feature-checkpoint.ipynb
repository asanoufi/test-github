# %%
#Engineering % to seasons best as a output measurment

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)

# %%
#Load columns needed

cols_needed = [
    'RaceId',
    'Date',
    'AthleteName',
    'AthleteGenderName',
    'RaceEventName',
    'RaceEventDistance',
    'RaceEventSwimmingStyleName',
    'RaceEventIsRelay',
    'PoolLength',
    'PhaseName',
    'RaceTime',
    'CompetitionName']

df = pd.read_csv('Nemo.csv', usecols = cols_needed)
print(df.shape)
df.head()
# Out:
# (2837, 12)
#                                  RaceId  PoolLength        Date  RaceEventDistance  RaceEventIsRelay      RaceEventName RaceEventSwimmingStyleName     AthleteName AthleteGenderName  \
# 0  003223f3-ae33-4dba-8fc9-365f7356ac4f          25  14/12/2024                 50             False  50 m Breaststroke               Breaststroke  Angharad Evans             Women
# 1  0066b686-e4f1-414e-b79d-31bbbf61ef55          50  19/11/2025                200             False    200 m Freestyle                  Freestyle  Freya Anderson             Women
# 2  00721f02-0a18-4031-bdc8-bdad872a41b2          50  30/07/2022                200             False    200 m Freestyle                  Freestyle      Evan Jones               Men
# 3  009e1505-8709-4103-9e30-6be7c52e5f02          50  05/04/2024                200             False   200 m Backstroke                 Backstroke    Holly McGill             Women
# ...

# %%
#INITIAL DATA CHECKS

# %%
#Check data types and missing values across columns
print(df.dtypes)
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# RaceId                            str
# PoolLength                      int64
# Date                              str
# RaceEventDistance               int64
# RaceEventIsRelay                 bool
# RaceEventName                     str
# RaceEventSwimmingStyleName        str
# AthleteName                       str
# AthleteGenderName                 str
# CompetitionName                   str
# PhaseName                         str
# RaceTime                      float64
# dtype: object
#
# Missing values per column:
# RaceId                        0
# PoolLength                    0
# Date                          0
# RaceEventDistance             0
# RaceEventIsRelay              0
# RaceEventName                 0
# RaceEventSwimmingStyleName    0
# AthleteName                   0
# AthleteGenderName             0
# CompetitionName               0
# PhaseName                     0
# RaceTime                      0
# dtype: int64

# %%
#Check unique values in categorical columns
##Sanity checks for poollength, relay, phasename, gender, and comp columns
###Will need to filter out unnecessary "competition names"

for col in ['PoolLength', 'RaceEventIsRelay', 'PhaseName', 'AthleteGenderName', 'CompetitionName']:
    print(f"\n--- {col} ---")
    print(df[col].value_counts())
# Out:
# --- PoolLength ---
# PoolLength
# 50    2379
# 25     458
# Name: count, dtype: int64
#
# --- RaceEventIsRelay ---
# RaceEventIsRelay
# False    2581
# True      256
# Name: count, dtype: int64
#
# --- PhaseName ---
# PhaseName
# Heat           1262
# Final          1185
# B-Final         136
# Semi-Final      131
# Time Trial       96
# C-Final          23
# Round of 16       2
# D-Final           2
# Name: count, dtype: int64
#
# --- AthleteGenderName ---
# AthleteGenderName
# Women    1603
# Men      1234
# Name: count, dtype: int64
#
# --- CompetitionName ---
# CompetitionName
# British Championships                   386
# Edinburgh International                 358
# Scottish Short Course                   290
# Scottish Nationals                      180
# Time Trial                              173
# BUCS Championships                      166
# Sette Colli                             156
# European Championships                  155
# ...

# %%
#Check racetime distribution
##Checks for missing values, implausible values, gen. distribution

print(df['RaceTime'].describe())
print(f"\nZero or negative RaceTimes: {(df['RaceTime'] <= 0).sum()}")
print(f"Missing RaceTimes: {df['RaceTime'].isnull().sum()}")
# Out:
# count    2837.000000
# mean       99.086567
# std        82.376016
# min         0.000000
# 25%        52.700000
# 50%        65.910000
# 75%       127.450000
# max      1032.110000
# Name: RaceTime, dtype: float64
#
# Zero or negative RaceTimes: 100
# Missing RaceTimes: 0

# %%
#Check date format

##Convert Date to datetime if not already
df['Date'] = pd.to_datetime(df['Date'])

#Confirm conversion worked
print(df['Date'].dtype)
print(f"Date range: {df['Date'].min()} to {df['Date'].max()}")
# Out:
# datetime64[us]
# Date range: 2022-01-20 00:00:00 to 2025-12-31 00:00:00
# C:\Users\adhamz\AppData\Local\Temp\ipykernel_23780\858547553.py:4: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
####Filter and clean
##Remove unnecessary rows
#Includes relay races, junk comp types, missing race_times, phase filtering

#Inspect competitions where race time is 0

zero_rt = df[df['RaceTime'] == 0]

print(f"Total zero RaceTimes: {len(zero_rt)}")
print(f"\n--- CompetitionName ---")
print(zero_rt['CompetitionName'].value_counts())
print(f"\n--- PhaseName ---")
print(zero_rt['PhaseName'].value_counts())
# Out:
# Total zero RaceTimes: 100
#
# --- CompetitionName ---
# CompetitionName
# BUCS Championships                      23
# Training                                22
# Scottish Nationals                      15
# British Summer Championships            10
# CERTIFICATION 2025                       7
# Scottish Short Course                    5
# European U23 Championships               3
# CERTIFICATION 2022                       3
# CERTIFICATION 2023                       2
# European Junior Championships            2
# City of Manchester Winter Qualifiers     2
# Glasgow International                    1
# Mare Nostrum Barcelona                   1
# Certification 2026                       1
# European Championships                   1
# Time Trial                               1
# Sette Colli                              1
# Name: count, dtype: int64
#
# --- PhaseName ---
# PhaseName
# Final         50
# Heat          34
# Semi-Final    15
# B-Final        1
# ...

# %%
#Removing rows where race time is 0 and all rows that contain junk CompetitionName

junk_competitions = [
    'Training'
    'CERTIFICATION 2022',
    'CERTIFICATION 2023',
    'CERTIFICATION 2025',
    'Certification 2026',
]

# Check how many rows this affects in total (any 0 racetime removals?)
junk_mask = df['CompetitionName'].isin(junk_competitions)
print(f"Rows in junk competitions (any RaceTime): {junk_mask.sum()}")
print(f"Of which RaceTime == 0: {(df['RaceTime'][junk_mask] == 0).sum()}")
print(f"Of which RaceTime > 0: {(df['RaceTime'][junk_mask] > 0).sum()}")
# Out:
# Rows in junk competitions (any RaceTime): 75
# Of which RaceTime == 0: 10
# Of which RaceTime > 0: 65

# %%
junk_competitions = [
    'Training',
    'CERTIFICATION 2022',
    'CERTIFICATION 2023',
    'CERTIFICATION 2025',
    'Certification 2026',
]

junk_mask = df['CompetitionName'].isin(junk_competitions)
junk_rows = df[junk_mask]

print(f"Total junk rows: {len(junk_rows)}")
print(f"junk_rows shape: {junk_rows.shape}")
print(junk_rows['CompetitionName'].value_counts())
print(f"\nRaceTime==0 within junk rows: {(junk_rows['RaceTime']==0).sum()}")
print(f"RaceTime>0 within junk rows: {(junk_rows['RaceTime']>0).sum()}")
# Out:
# Total junk rows: 132
# junk_rows shape: (132, 12)
# CompetitionName
# CERTIFICATION 2025    35
# Training              33
# CERTIFICATION 2023    26
# CERTIFICATION 2022    24
# Certification 2026    14
# Name: count, dtype: int64
#
# RaceTime==0 within junk rows: 35
# RaceTime>0 within junk rows: 97

# %%
junk_competitions = [
    'Training',
    'CERTIFICATION 2022',
    'CERTIFICATION 2023',
    'CERTIFICATION 2025',
    'Certification 2026',]

df_clean = df.copy()

#Remove relays
df_clean = df_clean[df_clean['RaceEventIsRelay'] == False]
print(f"After removing relays: {len(df_clean)}")

#Remove RaceTime == 0
df_clean = df_clean[df_clean['RaceTime'] > 0]
print(f"After removing RaceTime==0: {len(df_clean)}")

#Remove junk competitions
df_clean = df_clean[~df_clean['CompetitionName'].isin(junk_competitions)]
print(f"After removing junk competitions: {len(df_clean)}")

print(f"\nTotal removed: {len(df) - len(df_clean)}")
# Out:
# After removing relays: 2581
# After removing RaceTime==0: 2507
# After removing junk competitions: 2447
#
# Total removed: 390

# %%
###Assigning season IDs
##Assume season runs September -> August. 
##E.g. 15Nov2024 -> 2024/2025, 10Mar2025 -> 2024/2025

def assign_season(date):
    if date.month >=9:
        start_year = date.year
    else:
        start_year = date.year - 1
    return f"{start_year}_{str(start_year+1)[-2:]}"

df_clean['SeasonId'] = df_clean['Date'].apply(assign_season)

print(df_clean['SeasonId'].value_counts().sort_index())
# Out:
# SeasonId
# 2021_22    384
# 2022_23    584
# 2023_24    758
# 2024_25    599
# 2025_26    122
# Name: count, dtype: int64

# %%
##Identify short course races for conversion
#SC converted to LC-equiveleant time before compared 

#Flag which rows need converting

df_clean['CourseType'] = df_clean['PoolLength'].map({50: 'LC', 25: 'SC'})

print(df_clean['CourseType'].value_counts())
print(f"\nSC races by month:")
print(df_clean[df_clean['CourseType']=='SC']['Date'].dt.month.value_counts().sort_index())
# Out:
# CourseType
# LC    2022
# SC     425
# Name: count, dtype: int64
#
# SC races by month:
# Date
# 9       8
# 10     13
# 11     12
# 12    392
# Name: count, dtype: int64

# %%
##Is there a single recurring short course championship
#Check SC competition names

print(df_clean[df_clean['CourseType']=='SC']['CompetitionName'].value_counts())
# Out:
# CompetitionName
# Scottish Short Course                   285
# European Championships                   83
# Time Trial                               23
# World Championships                      16
# National Winter Championships             8
# BUCS Championships                        8
# City of Manchester Winter Qualifiers      2
# Name: count, dtype: int64

# %%
df_lc = df_clean[df_clean['CourseType'] == 'LC'].copy()
print(f"LC-only dataset: {len(df_lc)} rows")
print(df_lc['SeasonId'].value_counts().sort_index())
# Out:
# LC-only dataset: 2022 rows
# SeasonId
# 2021_22    384
# 2022_23    497
# 2023_24    659
# 2024_25    482
# Name: count, dtype: int64

# %%
###Calculating Season's Best (Expanding minimum)
##Athlete+Event+Season combination has a minimum race_time not including current race

df_lc = df_lc.sort_values(['AthleteName', 'RaceEventName', 'Date']).reset_index(drop=True)

#Quick check on how many athlete+event combinations we have
#and how many races per combination on average
group_sizes = df_lc.groupby(['AthleteName', 'RaceEventName']).size()
print(f"Number of athlete+event combinations: {len(group_sizes)}")
print(f"Races per combination - describe:")
print(group_sizes.describe())
print(f"\nCombinations with only 1 race (no prior season best possible within-season):")
print((group_sizes == 1).sum())
# Out:
# Number of athlete+event combinations: 130
# Races per combination - describe:
# count    130.000000
# mean      15.553846
# std       15.207639
# min        1.000000
# 25%        3.000000
# 50%        9.000000
# 75%       26.750000
# max       62.000000
# dtype: float64
#
# Combinations with only 1 race (no prior season best possible within-season):
# 18

# %%
#Inspect the 18 'single race' combinations

single_race = group_sizes[group_sizes == 1].index
print(f"Athlete-Event combinations with only 1 race:")
for athlete, event in single_race:
    print(f"  {athlete} — {event}")
# Out:
# Athlete-Event combinations with only 1 race:
#   David Annis — 100 m Backstroke
#   David Annis — 100 m Butterfly
#   Duncan Scott — 50 m Backstroke
#   Duncan Scott — 50 m Butterfly
#   Finlay Davies — 100 m Backstroke
#   Finlay Davies — 200 m Breaststroke
#   George Smith — 200 m Backstroke
#   Jack McMillan — 100 m Butterfly
#   Jack McMillan — 50 m Freestyle
#   Jamie Robertson — 100 m Freestyle
#   Katie Shanahan — 100 m Butterfly
#   Katie Shanahan — 400 m Freestyle
#   Katie Shanahan — 50 m Backstroke
#   Lucy Grieve — 200 m Freestyle
#   Lucy Grieve — 50 m Backstroke
#   Lucy Hope — 100 m Backstroke
#   Suzie McNair — 200 m Breaststroke
#   Thomas Dean — 100 m Butterfly

# %%
##Calculating season's best so far
#Calculate the best (minimum) RaceTime from all PREVIOUS races in that season only

def expanding_min_excl_current(series):
    #shift(1) excludes the current row from its own "best so far"
    return series.shift(1).expanding().min()

df_lc['season_best_so_far'] = (
    df_lc.groupby(['AthleteName', 'RaceEventName', 'SeasonId'])['RaceTime']
    .transform(expanding_min_excl_current))

#Check how many rows have NaN (i.e. first race of the season for that event)
print(f"Rows with no season_best_so_far (first race of season): {df_lc['season_best_so_far'].isnull().sum()}")
print(f"Total rows: {len(df_lc)}")

#Check on one athlete-event-season
sample = df_lc[(df_lc['AthleteName']==df_lc['AthleteName'].iloc[12]) & 
               (df_lc['RaceEventName']==df_lc['RaceEventName'].iloc[12])]
print(sample[['Date','SeasonId','RaceTime','season_best_so_far']].head(15))
# Out:
# Rows with no season_best_so_far (first race of season): 324
# Total rows: 2022
#          Date SeasonId  RaceTime  season_best_so_far
# 8  2023-12-03  2023_24     67.77                 NaN
# 9  2023-12-03  2023_24     67.27               67.77
# 10 2023-12-14  2023_24     67.59               67.27
# 11 2023-12-14  2023_24     66.34               67.27
# 12 2024-01-20  2023_24     68.52               66.34
# 13 2024-02-24  2023_24     67.10               66.34
# 14 2024-02-24  2023_24     66.65               66.34
# 15 2024-03-08  2023_24     68.27               66.34
# 16 2024-03-08  2023_24     66.25               66.34
# 17 2024-04-07  2023_24     66.54               66.25
# 18 2024-04-07  2023_24     66.27               66.25
# 19 2024-05-26  2023_24     65.54               66.25
# 20 2024-05-26  2023_24     66.80               65.54
# 21 2024-06-21  2023_24     65.91               65.54
# 22 2024-06-21  2023_24     66.92               65.54

# %%
#Build Pre-season best lookup

#First, calculate each athlete-event's best time Per Season (full season, not expanding)
season_bests = (
    df_lc.groupby(['AthleteName', 'RaceEventName', 'SeasonId'])['RaceTime']
    .min()
    .reset_index()
    .rename(columns={'RaceTime': 'full_season_best'}))

#Create a mapping of season -> previous season
#e.g. "2022_23" -> "2021_22"
def previous_season(season_id):
    start_year = int(season_id.split('_')[0])
    prev_start = start_year - 1
    return f"{prev_start}_{str(start_year)[-2:]}"

season_bests['PrevSeason'] = season_bests['SeasonId'].apply(previous_season)

#Self-merge: for each (athlete-event-season), find the full_season_best from PrevSeason
prior_lookup = season_bests.merge(
    season_bests[['AthleteName', 'RaceEventName', 'SeasonId', 'full_season_best']],
    left_on=['AthleteName', 'RaceEventName', 'PrevSeason'],
    right_on=['AthleteName', 'RaceEventName', 'SeasonId'],
    suffixes=('', '_prior'),
    how='left'
)[['AthleteName', 'RaceEventName', 'SeasonId', 'full_season_best_prior']]
prior_lookup = prior_lookup.rename(columns={'full_season_best_prior': 'prior_season_best'})

#Merge back onto df_lc
df_lc = df_lc.merge(prior_lookup, on=['AthleteName', 'RaceEventName', 'SeasonId'], how='left')

#Check coverage
print(f"Rows where season_best_so_far is NaN: {df_lc['season_best_so_far'].isnull().sum()}")
print(f"Of those, rows where prior_season_best is also NaN: {(df_lc['season_best_so_far'].isnull() & df_lc['prior_season_best'].isnull()).sum()}")
# Out:
# Rows where season_best_so_far is NaN: 324
# Of those, rows where prior_season_best is also NaN: 136

# %%
##Investigating the 136 unresolvable rows

unresolvable = df_lc[df_lc['season_best_so_far'].isnull() & df_lc['prior_season_best'].isnull()]

print(f"Total unresolvable rows: {len(unresolvable)}")
print(f"\nBy season:")
print(unresolvable['SeasonId'].value_counts().sort_index())
# Out:
# Total unresolvable rows: 136
#
# By season:
# SeasonId
# 2021_22    67
# 2022_23    24
# 2023_24    37
# 2024_25     8
# Name: count, dtype: int64

# %%
##Build final comparison time and outcome variable

#Build outcome variable

df_lc['comparison_time'] = df_lc['season_best_so_far'].fillna(df_lc['prior_season_best'])
df_lc['comparison_source'] = np.where(
    df_lc['season_best_so_far'].notnull(), 'current_season',
    np.where(df_lc['prior_season_best'].notnull(), 'prior_season', 'none')
)

df_lc['pct_from_season_best'] = (df_lc['RaceTime'] / df_lc['comparison_time']) * 100
df_lc['is_new_season_best'] = df_lc['pct_from_season_best'] < 100

#Summary
print(df_lc['comparison_source'].value_counts())
print(f"\npct_from_season_best summary (excluding 'none'):")
print(df_lc[df_lc['comparison_source']!='none']['pct_from_season_best'].describe())

#Check
sample = df_lc[(df_lc['AthleteName']==df_lc['AthleteName'].iloc[12]) & 
               (df_lc['RaceEventName']==df_lc['RaceEventName'].iloc[12])]
print(sample[['Date','SeasonId','RaceTime','comparison_time','comparison_source','pct_from_season_best','is_new_season_best']].head(15))
# Out:
# comparison_source
# current_season    1698
# prior_season       188
# none               136
# Name: count, dtype: int64
#
# pct_from_season_best summary (excluding 'none'):
# count    1886.000000
# mean      101.033720
# std         4.579904
# min        49.174603
# 25%        99.814973
# 50%       100.807475
# 75%       101.878126
# max       203.970303
# Name: pct_from_season_best, dtype: float64
#          Date SeasonId  RaceTime  comparison_time comparison_source  pct_from_season_best  is_new_season_best
# 8  2023-12-03  2023_24     67.77              NaN              none                   NaN               False
# 9  2023-12-03  2023_24     67.27            67.77    current_season             99.262210                True
# 10 2023-12-14  2023_24     67.59            67.27    current_season            100.475695               False
# 11 2023-12-14  2023_24     66.34            67.27    current_season             98.617512                True
# ...

# %%
##Investigating implausible pct_from_season_best values
#49% and 200% is implausible for percentage to season's best

extreme = df_lc[(df_lc['pct_from_season_best'] < 90) | (df_lc['pct_from_season_best'] > 110)]
print(f"Rows with pct_from_season_best outside 90-110: {len(extreme)}")
print(extreme[['AthleteName','RaceEventName','Date','SeasonId','RaceTime','comparison_time','comparison_source','pct_from_season_best']].sort_values('pct_from_season_best'))
# Out:
# Rows with pct_from_season_best outside 90-110: 6
#       AthleteName     RaceEventName       Date SeasonId  RaceTime  comparison_time comparison_source  pct_from_season_best
# 820  Holly McGill  100 m Backstroke 2022-07-09  2021_22     30.98            63.00    current_season             49.174603
# 314  Duncan Scott          200 m IM 2023-06-30  2022_23    128.41           116.72    current_season            110.015422
# 331  Duncan Scott          200 m IM 2024-06-28  2023_24    129.92           115.91    current_season            112.086964
# 822  Holly McGill  100 m Backstroke 2022-07-30  2021_22     62.41            30.98    current_season            201.452550
# 821  Holly McGill  100 m Backstroke 2022-07-30  2021_22     62.54            30.98    current_season            201.872176
# 823  Holly McGill  100 m Backstroke 2023-03-10  2022_23     63.19            30.98      prior_season            203.970303

# %%
##Flag the bad row (#820, McGill 100m Back 09072022)
##Then rerun season's best pipeline

bad_race_ids = ['1ab033a6-63dc-4611-b0fa-63a54e645cee']

df_lc = df_lc[~df_lc['RaceId'].isin(bad_race_ids)].copy()
print(f"df_lc shape after removing bad RaceId: {df_lc.shape}")

#Re-run expanding minimum
df_lc['season_best_so_far'] = (
    df_lc.groupby(['AthleteName', 'RaceEventName', 'SeasonId'])['RaceTime']
    .transform(expanding_min_excl_current)
)

#Re-run prior season best
season_bests = (
    df_lc.groupby(['AthleteName', 'RaceEventName', 'SeasonId'])['RaceTime']
    .min()
    .reset_index()
    .rename(columns={'RaceTime': 'full_season_best'})
)
season_bests['PrevSeason'] = season_bests['SeasonId'].apply(previous_season)

prior_lookup = season_bests.merge(
    season_bests[['AthleteName', 'RaceEventName', 'SeasonId', 'full_season_best']],
    left_on=['AthleteName', 'RaceEventName', 'PrevSeason'],
    right_on=['AthleteName', 'RaceEventName', 'SeasonId'],
    suffixes=('', '_prior'),
    how='left'
)[['AthleteName', 'RaceEventName', 'SeasonId', 'full_season_best_prior']]
prior_lookup = prior_lookup.rename(columns={'full_season_best_prior': 'prior_season_best'})

df_lc = df_lc.drop(columns=['prior_season_best'], errors='ignore')
df_lc = df_lc.merge(prior_lookup, on=['AthleteName', 'RaceEventName', 'SeasonId'], how='left')

#Re-run outcome variable

df_lc['comparison_time'] = df_lc['season_best_so_far'].fillna(df_lc['prior_season_best'])
df_lc['comparison_source'] = np.where(
    df_lc['season_best_so_far'].notnull(), 'current_season',
    np.where(df_lc['prior_season_best'].notnull(), 'prior_season', 'none')
)
df_lc['pct_from_season_best'] = (df_lc['RaceTime'] / df_lc['comparison_time']) * 100
df_lc['is_new_season_best'] = df_lc['pct_from_season_best'] < 100

print(df_lc[df_lc['comparison_source']!='none']['pct_from_season_best'].describe())
# Out:
# df_lc shape after removing bad RaceId: (2021, 19)
# count    1885.000000
# mean      100.898376
# std         1.780316
# min        92.837135
# 25%        99.814678
# 50%       100.806037
# 75%       101.864293
# max       112.086964
# Name: pct_from_season_best, dtype: float64
