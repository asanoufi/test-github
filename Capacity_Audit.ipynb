# %%
import pandas as pd
import numpy as np
# !pip install openpyxl

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)
# Out:
# Requirement already satisfied: openpyxl in C:\Users\adhamz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in C:\Users\adhamz\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openpyxl) (2.0.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\adhamz\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
df_capacity = pd.read_csv('SnC Capacity Testing 3.csv')
print(df_capacity.shape)
df_capacity.head()
# Out:
# (598, 11)
#          Date            About             by Exercise  Duration  Reps  Test Rating  Comments           Athlete_Exercise_Date_Key                            event-uuid  \
# 0  03-12-2025       Dean Fearn  Matt Milligan  Pull Up       NaN  10.0          NaN       NaN       Dean Fearn-Pull Up-03/12/2025  47b91200-2946-42e6-96a2-2b9a168e323d
# 1  03-12-2025  Jamie Robertson  Matt Milligan  Pull Up       NaN  26.0          NaN       NaN  Jamie Robertson-Pull Up-03/12/2025  da51bf02-2cfa-48ea-bb7a-98edbc005ec5
# 2  01-12-2025     Holly McGill  Matt Milligan  Pull Up       NaN  13.0          NaN       NaN     Holly McGill-Pull Up-01/12/2025  643cd31e-0e7e-485a-873f-200592bfb92a
# 3  01-12-2025      Lucy Grieve  Matt Milligan  Pull Up       NaN  14.0          NaN       NaN      Lucy Grieve-Pull Up-01/12/2025  0f998b90-ada2-431b-a72d-05eb6d310b12
# 4  01-12-2025     George Smith  Matt Milligan  Pull Up       NaN  31.0          NaN       NaN     George Smith-Pull Up-01/12/2025  46a496dc-7284-4b5f-ba89-0011604d051b
#
#                              group-uuid
# 0  75c7304c-b6d7-411f-996d-0c30f072ddc5
# 1  b72e798f-44f1-4890-ba4e-09c9e1219a94
# 2  97800a3e-4bba-4df0-83db-b8e869a9294d
# 3  02326a70-b50e-466a-8aef-fa9545c0f17f
# 4  71964f5d-f6bc-475c-9da3-fe0dcccb4fdb

# %%
# %run "./audit_utils.ipynb"

# %%
var_summary, temporal = run_audit(
    df=df_capacity,
    dataset_name='SnC Capacity',
    athlete_col='About',
    date_col='Date'
)
# Out:
# ==================================================
# AUDIT COMPLETE: SnC Capacity
# ==================================================
# Total variables: 11
# Total rows: 598
#
# Variable role breakdown:
#   Identifier                               6
#   Predictor candidate                      2
#   Exclude (structurally empty)             2
#   Sparse categorical - review              1
#
# Temporal coverage:
# Athletes: 16
# Date range: 2019-09-13 to 2025-12-03
# Mean obs/athlete: 37.38
# Mean gap (days): 35.85
#
# Saved: SnC_Capacity_audit.xlsx
